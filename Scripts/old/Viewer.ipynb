# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
os.environ['SNORKELDB'] = 'postgres:///lzirondi'
from snorkel import SnorkelSession
session = SnorkelSession()

from snorkel.models import candidate_subclass
relation = candidate_subclass('Causa', ['Substância', 'Evento_Adverso'])

cands = session.query(relation).filter(relation.split == 0).all()

from snorkel.viewer import SentenceNgramViewer
SentenceNgramViewer(cands, session)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# SentenceNgramViewer(cids=[[[4416], [4039, 4040, 5008, 5009], [3821]], [[300], [31, 32, 3155, 3156, 5196, 5197]…

# %%
#cands = session.query(relation).filter(relation.split == 0).all()
from snorkel.models.annotation import GoldLabel


print(session.query(GoldLabel).filter(GoldLabel.value == 1).all())

print(dir(GoldLabel))
# Out:
# [GoldLabel (lzirondi = 1), GoldLabel (lzirondi = 1), GoldLabel (lzirondi = 1), GoldLabel (lzirondi = 1)]
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__mapper__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__table__', '__tablename__', '__weakref__', '_decl_class_registry', '_sa_class_manager', 'candidate', 'candidate_id', 'key', 'key_id', 'metadata', 'value']
